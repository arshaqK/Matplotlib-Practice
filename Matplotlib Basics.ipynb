# %%
# %matplotlib inline
from matplotlib import pyplot as plt

# %%
plt.plot([1,2,3], [2,5,7])
plt.show()

# %%
plt.plot([1,2,3], [2,5,7])
plt.title("Matplotlib Practice")
plt.ylabel("This is y")
plt.xlabel("This is x")
plt.show()

# %%
x = [1,5,4]
y = [23,45,89]
x2 = [3,7,3]
y2 = [45,8,9]

plt.title("Second Chart")
plt.xlabel("X")
plt.ylabel("Y")
plt.scatter(x,y, label='first', linewidth=4, color ='Red')
plt.plot(x2, label='second')
plt.legend() 
plt.show()
